# %%
# Lebanese restaurent in Los Angeles

# Import required libraries
import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
import numpy as np
import requests
from bs4 import BeautifulSoup
import io
import folium
import matplotlib.cm as cm
import matplotlib.colors as colors
from sklearn.cluster import KMeans
import folium
from geopy.geocoders import Nominatim 
# %matplotlib inline

# %%
# DATA ACQUISITION

# List of districts and neighborhoods of Los Angeles
# Get data from wikipedia page, process the page with BeautifulSoup to extract the data
website_url = requests.get('https://en.wikipedia.org/wiki/List_of_districts_and_neighborhoods_of_Los_Angeles').text
soup = BeautifulSoup(website_url,'html')
# soup.prettify()
neighbourhoods_list = soup.findAll('ul')  # in this result set, the useful lists are the 3rd and 4th (table in 2 parts)
# Extracting neighborhoods' list
neighborhoods = []
for item in neighbourhoods_list[2].findAll('li'): # 3rd list
    neighborhoods.append(item.a.renderContents().decode("utf-8"))
for item in neighbourhoods_list[3].findAll('li'): # 4th list
    neighborhoods.append(item.a.renderContents().decode("utf-8"))

print('List of Los Angeles neighborhoods:\n' + "\n".join(neighborhoods))
# Out:
# List of Los Angeles neighborhoods:
# Angelino Heights
# Arleta
# Arlington Heights
# Arts District
# Atwater Village
# Baldwin Hills
# Baldwin Hills/Crenshaw
# Baldwin Village
# Baldwin Vista
# Beachwood Canyon
# Bel Air, Bel-Air or Bel Air Estates
# Benedict Canyon
# Beverly Crest
# Beverly Glen
# Beverly Grove
# Beverly Hills Post Office
# Beverly Park
# Beverlywood
# Boyle Heights
# Brentwood
# Brentwood Circle
# Brentwood Glen
# Broadway-Manchester
# Brookside
# Bunker Hill
# Cahuenga Pass
# Canoga Park
# Canterbury Knolls
# Carthay
# Castle Heights
# Central-Alameda
# Central City
# Century City
# Chatsworth
# Chesterfield Square
# Cheviot Hills
# Chinatown
# Civic Center
# Crenshaw
# Crestwood Hills
# Cypress Park
# Del Rey
# Downtown
# Eagle Rock
# East Gate Bel Air
# East Hollywood
# Echo Park
# Edendale
# El Sereno
# Elysian Heights
# Elysian Park
# Elysian Valley
# Encino
# Exposition Park
# Faircrest Heights
# Fairfax
# Fashion District
# Filipinotown, Historic
# Financial District
# Florence
# Flower District
# Franklin Hills
# Gallery Row
# Garvanza
# Glassell Park
# Gramercy Park
# Granada Hills
# Green Meadows
# Griffith Park
# Hancock Park
# Harbor City
# Harbor Gateway
# Harvard Heights
# Harvard Park
# Hermon
# Highland Park
# Historic Core
# Hollywood
# Hollywood Dell
# Hollywood Hills
# Hollywood Hills West
# Holmby Hills
# Hyde Park
# Jefferson Park
# Jewelry District
# Kinney Heights
# Koreatown
# Ladera
# Lafayette Square
# Lake Balboa
# Lake View Terrace
# Larchmont
# Laurel Canyon
# Leimert Park
# Lincoln Heights
# Little Armenia
# Little Ethiopia
# Little Tokyo
# Los Feliz
# Manchester Square
# Mandeville Canyon
# Mar Vista
# Melrose Hill
# Mid-City
# Mid-Wilshire
# Miracle Mile
# Mission Hills
# Montecito Heights
# Monterey Hills
# Mount Olympus
# Mount Washington
# Nichols Canyon
# NoHo Arts District
# North Hills
# North Hollywood
# Northridge
# North University Park
# Old Bank District
# Outpost Estates
# Pacific Palisades
# Pacoima
# Palms
# Panorama City
# Park La Brea
# Picfair Village
# [33]
# Pico-Union
# Platinum Triangle
# Playa del Rey
# Playa Vista
# Porter Ranch
# Rancho Park
# Reseda
# Reynier Village
# Rose Hills
# Rustic Canyon
# San Pedro
# Sawtelle
# Shadow Hills
# Sherman Oaks
# Sherman Village
# Silver Lake
# Skid Row
# Solano Canyon
# South Central, Historic
# South Park
# South Robertson
# Spaulding Square
# Studio City
# Sunland
# Sunset Junction
# Sun Valley
# Sylmar
# Tarzana
# Terminal Island
# Thai Town
# Toluca Lake
# Toy District
# Tujunga
# University Hills
# University Park
# University Park, North
# Valley Glen
# Valley Village
# Van Nuys
# Venice
# Vermont Knolls
# Vermont-Slauson
# Vermont Square
# Vermont Vista
# Victor Heights
# Victoria Park
# Village Green
# Warehouse District
# Warner Center
# Watts
# West Adams
# Westchester
# Westdale
# Western Heights
# West Hills
# Westlake
# West Los Angeles
# Westside Village
# Westwood
# Westwood Village
# Whitley Heights
# Wholesale District
# Wilmington
# Wilshire Center
# Wilshire Park
# Windsor Square
# Winnetka
# Woodland Hills
# Yucca Corridor

# %%
# Correcting specific neighborhoods names
for n, i in enumerate(neighborhoods):
    if i == '[33]':
        neighborhoods[n] = 'Pico Robertson'
    if i == 'Bel Air, Bel-Air or Bel Air Estates':
        neighborhoods[n] = 'Bel Air'

neighborhoods = [s.replace('-', ' ') for s in neighborhoods]
        
print('List of Los Angeles neighborhoods:\n' + "\n".join(neighborhoods))
# Out:
# List of Los Angeles neighborhoods:
# Angelino Heights
# Arleta
# Arlington Heights
# Arts District
# Atwater Village
# Baldwin Hills
# Baldwin Hills/Crenshaw
# Baldwin Village
# Baldwin Vista
# Beachwood Canyon
# Bel Air
# Benedict Canyon
# Beverly Crest
# Beverly Glen
# Beverly Grove
# Beverly Hills Post Office
# Beverly Park
# Beverlywood
# Boyle Heights
# Brentwood
# Brentwood Circle
# Brentwood Glen
# Broadway Manchester
# Brookside
# Bunker Hill
# Cahuenga Pass
# Canoga Park
# Canterbury Knolls
# Carthay
# Castle Heights
# Central Alameda
# Central City
# Century City
# Chatsworth
# Chesterfield Square
# Cheviot Hills
# Chinatown
# Civic Center
# Crenshaw
# Crestwood Hills
# Cypress Park
# Del Rey
# Downtown
# Eagle Rock
# East Gate Bel Air
# East Hollywood
# Echo Park
# Edendale
# El Sereno
# Elysian Heights
# Elysian Park
# Elysian Valley
# Encino
# Exposition Park
# Faircrest Heights
# Fairfax
# Fashion District
# Filipinotown, Historic
# Financial District
# Florence
# Flower District
# Franklin Hills
# Gallery Row
# Garvanza
# Glassell Park
# Gramercy Park
# Granada Hills
# Green Meadows
# Griffith Park
# Hancock Park
# Harbor City
# Harbor Gateway
# Harvard Heights
# Harvard Park
# Hermon
# Highland Park
# Historic Core
# Hollywood
# Hollywood Dell
# Hollywood Hills
# Hollywood Hills West
# Holmby Hills
# Hyde Park
# Jefferson Park
# Jewelry District
# Kinney Heights
# Koreatown
# Ladera
# Lafayette Square
# Lake Balboa
# Lake View Terrace
# Larchmont
# Laurel Canyon
# Leimert Park
# Lincoln Heights
# Little Armenia
# Little Ethiopia
# Little Tokyo
# Los Feliz
# Manchester Square
# Mandeville Canyon
# Mar Vista
# Melrose Hill
# Mid City
# Mid Wilshire
# Miracle Mile
# Mission Hills
# Montecito Heights
# Monterey Hills
# Mount Olympus
# Mount Washington
# Nichols Canyon
# NoHo Arts District
# North Hills
# North Hollywood
# Northridge
# North University Park
# Old Bank District
# Outpost Estates
# Pacific Palisades
# Pacoima
# Palms
# Panorama City
# Park La Brea
# Picfair Village
# Pico Robertson
# Pico Union
# Platinum Triangle
# Playa del Rey
# Playa Vista
# Porter Ranch
# Rancho Park
# Reseda
# Reynier Village
# Rose Hills
# Rustic Canyon
# San Pedro
# Sawtelle
# Shadow Hills
# Sherman Oaks
# Sherman Village
# Silver Lake
# Skid Row
# Solano Canyon
# South Central, Historic
# South Park
# South Robertson
# Spaulding Square
# Studio City
# Sunland
# Sunset Junction
# Sun Valley
# Sylmar
# Tarzana
# Terminal Island
# Thai Town
# Toluca Lake
# Toy District
# Tujunga
# University Hills
# University Park
# University Park, North
# Valley Glen
# Valley Village
# Van Nuys
# Venice
# Vermont Knolls
# Vermont Slauson
# Vermont Square
# Vermont Vista
# Victor Heights
# Victoria Park
# Village Green
# Warehouse District
# Warner Center
# Watts
# West Adams
# Westchester
# Westdale
# Western Heights
# West Hills
# Westlake
# West Los Angeles
# Westside Village
# Westwood
# Westwood Village
# Whitley Heights
# Wholesale District
# Wilmington
# Wilshire Center
# Wilshire Park
# Windsor Square
# Winnetka
# Woodland Hills
# Yucca Corridor

# %%
# Forming the neighborhoods dataframe
columns = ['Neighborhood']
neighborhoods_df = pd.DataFrame(columns = columns)
neighborhoods_df['Neighborhood'] = neighborhoods
print('There are {} neighborhoods in the dataframe.'.format(neighborhoods_df.shape[0]))
neighborhoods_df.head(10)
# Out:
# There are 195 neighborhoods in the dataframe.
#              Neighborhood
# 0        Angelino Heights
# 1                  Arleta
# 2       Arlington Heights
# 3           Arts District
# 4         Atwater Village
# 5           Baldwin Hills
# 6  Baldwin Hills/Crenshaw
# 7         Baldwin Village
# 8           Baldwin Vista
# 9        Beachwood Canyon

# %%
# Getting the geograpical coordinates of each neighborhood
latitudes = []
longitudes = []

for neigh in neighborhoods_df['Neighborhood']:
    location = None
    for k in range(10):
        try:
            address = '{}, Los Angeles, US'.format(neigh)
            geolocator = Nominatim(user_agent="LA_explorer")
            location = geolocator.geocode(address)
            latitude = location.latitude
            longitude = location.longitude
            latitudes.append(latitude)
            longitudes.append(longitude)
            print('The location coordinates of {} are {} and {}'.format(neigh, latitude, longitude))
            break
        except:
            pass
    if location is None:
        latitudes.append(0)
        longitudes.append(0)
print('Done!')
# Out:
# The location coordinates of Angelino Heights are 34.0702889 and -118.2547965
# The location coordinates of Arleta are 34.2413266 and -118.4322047
# The location coordinates of Arlington Heights are 34.0434937 and -118.3213735
# The location coordinates of Arts District are 34.0412389 and -118.2344503
# The location coordinates of Atwater Village are 34.1186975 and -118.2623924
# The location coordinates of Baldwin Hills/Crenshaw are 34.0075684 and -118.3505956
# The location coordinates of Beachwood Canyon are 34.1222919 and -118.3213845
# The location coordinates of Bel Air are 34.0988833 and -118.4598811
# The location coordinates of Benedict Canyon are 34.0447702 and -118.4000223
# The location coordinates of Beverly Crest are 34.1167701 and -118.4322607
# The location coordinates of Beverly Glen are 34.1077855 and -118.4456361
# The location coordinates of Beverly Grove are 34.0760338 and -118.3699723
# The location coordinates of Beverly Park are 34.06376935 and -118.26468959898818
# The location coordinates of Beverlywood are 34.0466335 and -118.395038
# The location coordinates of Boyle Heights are 34.0436892 and -118.2097684
# The location coordinates of Brentwood are 34.0521403 and -118.4740699
# The location coordinates of Broadway Manchester are 33.9410149 and -118.2744036
# The location coordinates of Brookside are 34.0536909 and -118.2427666
# The location coordinates of Bunker Hill are 34.0550659 and -118.2512228
# The location coordinates of Cahuenga Pass are 34.0968666 and -118.3295078
# The location coordinates of Canoga Park are 34.2010776 and -118.5978259
# The location coordinates of Canterbury Knolls are 33.842759599999994 and -118.12973131412647
# The location coordinates of Carthay are 34.0611213 and -118.3672997
# The location coordinates of Central Alameda are 34.004015 and -118.2477844
# The location coordinates of Century City are 34.0574263 and -118.4147267
# The location coordinates of Chatsworth are 34.2595715 and -118.6023247
# The location coordinates of Chesterfield Square are 33.9834737 and -118.3136513
# The location coordinates of Cheviot Hills are 34.0405878 and -118.4098875
# The location coordinates of Chinatown are 34.0638402 and -118.2358676
# The location coordinates of Civic Center are 34.057560699999996 and -118.24680989487618
# The location coordinates of Crenshaw are 33.9252122 and -118.3265295
# The location coordinates of Cypress Park are 34.0922322 and -118.2245179
# The location coordinates of Del Rey are 33.9896527 and -118.4243437
# The location coordinates of Downtown are 34.0428494 and -118.2476732
# The location coordinates of Eagle Rock are 34.1366877 and -118.2076796
# The location coordinates of East Hollywood are 34.0904277 and -118.2966254
# The location coordinates of Echo Park are 34.0779819 and -118.2567824
# The location coordinates of Edendale are 34.1075157 and -118.2659493
# The location coordinates of El Sereno are 34.0811213 and -118.1778495
# The location coordinates of Elysian Heights are 34.09954795 and -118.24471480448986
# The location coordinates of Elysian Park are 34.0774343 and -118.2386204
# The location coordinates of Elysian Valley are 34.0959128 and -118.2420326
# The location coordinates of Encino are 34.1591324 and -118.5016166
# The location coordinates of Exposition Park are 34.01365405 and -118.28721058194556
# The location coordinates of Fairfax are 34.0791555 and -118.3522844
# The location coordinates of Fashion District are 34.036622 and -118.2590687
# The location coordinates of Financial District are 34.050248100000005 and -118.25577504198614
# The location coordinates of Florence are 33.9741588 and -118.2432856
# The location coordinates of Flower District are 34.04096425 and -118.24939703818897
# The location coordinates of Gallery Row are 34.04668705 and -118.24948972158668
# The location coordinates of Garvanza are 34.1195777 and -118.18062645261816
# The location coordinates of Glassell Park are 34.1161201 and -118.2289627
# The location coordinates of Gramercy Park are 33.9511938 and -118.3093275
# The location coordinates of Granada Hills are 34.2661558 and -118.5174342
# The location coordinates of Green Meadows are 33.9409877 and -118.2629968
# The location coordinates of Griffith Park are 34.1358143 and -118.2947892
# The location coordinates of Hancock Park are 34.0736782 and -118.3350551
# The location coordinates of Harbor City are 33.7972822 and -118.3004717
# The location coordinates of Harbor Gateway are 33.8542249 and -118.2992198
# The location coordinates of Harvard Heights are 34.0471105 and -118.3054828
# The location coordinates of Harvard Park are 33.9839471 and -118.3046228
# The location coordinates of Hermon are 34.10731415 and -118.18525103964701
# The location coordinates of Highland Park are 34.1099469 and -118.1969828
# The location coordinates of Historic Core are 34.04596205 and -118.25187366803968
# The location coordinates of Hollywood are 34.0980031 and -118.3295232
# The location coordinates of Hollywood Hills are 34.1311792 and -118.3355474
# The location coordinates of Hollywood Hills West are 34.1104847 and -118.3733879
# The location coordinates of Hyde Park are 33.9854024 and -118.3308614
# The location coordinates of Jefferson Park are 34.0296173 and -118.3224597
# The location coordinates of Jewelry District are 34.046206299999994 and -118.25416742423957
# The location coordinates of Koreatown are 34.0617342 and -118.3053732
# The location coordinates of Ladera are 33.9941792 and -118.3753543
# The location coordinates of Lake Balboa are 34.1811656 and -118.49523600143311
# The location coordinates of Lake View Terrace are 34.2763908 and -118.3611912
# The location coordinates of Larchmont are 34.0798375 and -118.3178702
# The location coordinates of Laurel Canyon are 34.1684654 and -118.3962958
# The location coordinates of Leimert Park are 34.007702 and -118.3320627
# The location coordinates of Lincoln Heights are 34.070929050000004 and -118.20988981653888
# The location coordinates of Little Armenia are 34.0981716 and -118.3044966
# The location coordinates of Little Tokyo are 34.0482168 and -118.24118143660098
# The location coordinates of Los Feliz are 34.1076561 and -118.2875062
# The location coordinates of Manchester Square are 33.966374 and -118.3133775
# The location coordinates of Mandeville Canyon are 34.0610395 and -118.4949801
# The location coordinates of Mar Vista are 34.0037605 and -118.4391641
# The location coordinates of Mid City are 34.0415271 and -118.3603703
# The location coordinates of Mid Wilshire are 34.0568616 and -118.3458032
# The location coordinates of Mission Hills are 34.2572249 and -118.4670285
# The location coordinates of Montecito Heights are 34.0895404 and -118.1942792
# The location coordinates of Mount Washington are 34.0988396 and -118.2211069
# The location coordinates of North Hills are 34.2429575 and -118.4854081
# The location coordinates of North Hollywood are 34.1729044 and -118.3740371
# The location coordinates of Northridge are 34.2345615 and -118.5369316
# The location coordinates of Pacific Palisades are 34.0480643 and -118.5264706
# The location coordinates of Pacoima are 34.2625025 and -118.427027
# The location coordinates of Palms are 34.0247328 and -118.4116152
# The location coordinates of Panorama City are 34.2242902 and -118.4453745
# The location coordinates of Park La Brea are 34.0674016 and -118.3552363
# The location coordinates of Pico Robertson are 34.053269 and -118.3869832
# The location coordinates of Pico Union are 34.0465669 and -118.2878942
# The location coordinates of Playa del Rey are 33.9550828 and -118.4367496
# The location coordinates of Playa Vista are 33.9759574 and -118.4181815
# The location coordinates of Porter Ranch are 34.2818164 and -118.5612714
# The location coordinates of Rancho Park are 34.0344461 and -118.42526320604608
# The location coordinates of Reseda are 34.2000784 and -118.5369884
# The location coordinates of Rustic Canyon are 34.0779966 and -118.5191281
# The location coordinates of San Pedro are 33.7358518 and -118.2922934
# The location coordinates of Sawtelle are 34.0361107 and -118.4503563
# The location coordinates of Shadow Hills are 34.2619469 and -118.3517463
# The location coordinates of Sherman Oaks are 34.1508718 and -118.4489865
# The location coordinates of Silver Lake are 34.0896518 and -118.2693735
# The location coordinates of Skid Row are 34.0440571 and -118.2438507
# The location coordinates of Solano Canyon are 34.0818871 and -118.234983
# The location coordinates of South Park are 33.9959019 and -118.2697722
# The location coordinates of Studio City are 34.1483989 and -118.3961877
# The location coordinates of Sunland are 34.2669466 and -118.3023
# The location coordinates of Sunset Junction are 34.0926493 and -118.2807954
# The location coordinates of Sun Valley are 34.2204227 and -118.3878945
# The location coordinates of Sylmar are 34.3076252 and -118.4492148
# The location coordinates of Tarzana are 34.1714436 and -118.5429789
# The location coordinates of Terminal Island are 33.7451061 and -118.26302201608382
# The location coordinates of Thai Town are 34.1018533 and -118.3048616
# The location coordinates of Toluca Lake are 34.1521688 and -118.3571417
# The location coordinates of Toy District are 34.0470483 and -118.24551021662734
# The location coordinates of Tujunga are 34.252225 and -118.2884105
# The location coordinates of University Hills are 34.0666487 and -118.1774401
# The location coordinates of University Park are 34.027449 and -118.2839493
# The location coordinates of University Park, North are 34.027449 and -118.2839493
# The location coordinates of Valley Glen are 34.1826379 and -118.4138666
# The location coordinates of Valley Village are 34.1637147 and -118.3965758
# The location coordinates of Van Nuys are 34.1866581 and -118.448729
# The location coordinates of Venice are 33.995044 and -118.4668875
# The location coordinates of Vermont Knolls are 33.9668188 and -118.29167
# The location coordinates of Vermont Slauson are 33.9836914 and -118.2915417
# The location coordinates of Vermont Square are 34.0019449 and -118.3002125
# The location coordinates of Vermont Vista are 33.9419475 and -118.2858138
# The location coordinates of Victoria Park are 34.0466887 and -118.3307729
# The location coordinates of Village Green are 34.0198711 and -118.3606643
# The location coordinates of Warner Center are 34.1811457 and -118.5974421
# The location coordinates of Watts are 33.9405674 and -118.2428485
# The location coordinates of West Adams are 34.0294356 and -118.3524833
# The location coordinates of Westchester are 33.9540977 and -118.4000468
# The location coordinates of Westdale are 34.03038925 and -118.4320124625026
# The location coordinates of Western Heights are 32.534063 and -96.85186
# The location coordinates of West Hills are 34.2032325 and -118.645476
# The location coordinates of Westlake are 34.0629226 and -118.2728204
# The location coordinates of West Los Angeles are 34.0463986 and -118.448135
# The location coordinates of Westwood are 34.0668947 and -118.4399448
# The location coordinates of Westwood Village are 34.0594537 and -118.4442462
# The location coordinates of Wholesale District are 34.0365749 and -118.2354342
# The location coordinates of Wilmington are 33.780018 and -118.2625711
# The location coordinates of Wilshire Center are 34.06151465 and -118.43277116196552
# The location coordinates of Wilshire Park are 34.06151465 and -118.43277116196552
# The location coordinates of Windsor Square are 34.0689734 and -118.3199885
# The location coordinates of Winnetka are 34.2058826 and -118.570934
# The location coordinates of Woodland Hills are 34.1684364 and -118.6058382
# Done!

# %%
# Add the obtained coordinates to our dataframe
neighborhoods_df['Latitude'] = latitudes
neighborhoods_df['Longitude'] = longitudes
# Drop those neighborhoods for which we could not find the coordinates
neighborhoods_df = neighborhoods_df[[a and b for a, b in zip(neighborhoods_df['Latitude'] != 0, neighborhoods_df['Longitude'] != 0)]].reset_index(drop=True)
print('There are {} neighborhoods in the dataframe.'.format(neighborhoods_df.shape[0]))
neighborhoods_df.head(10)
# Out:
# There are 155 neighborhoods in the dataframe.
#              Neighborhood   Latitude   Longitude
# 0        Angelino Heights  34.070289 -118.254796
# 1                  Arleta  34.241327 -118.432205
# 2       Arlington Heights  34.043494 -118.321374
# 3           Arts District  34.041239 -118.234450
# 4         Atwater Village  34.118698 -118.262392
# 5  Baldwin Hills/Crenshaw  34.007568 -118.350596
# 6        Beachwood Canyon  34.122292 -118.321384
# 7                 Bel Air  34.098883 -118.459881
# 8         Benedict Canyon  34.044770 -118.400022
# 9           Beverly Crest  34.116770 -118.432261

# %%
# Now we will get the data of area and population of each neighborhood

# We start by adding the new columns to the dataframe
neighborhoods_df['Population'] = [0 for i in range(neighborhoods_df.shape[0])]
neighborhoods_df['Area'] = [0 for i in range(neighborhoods_df.shape[0])]

# To get the area of each neighborhood, we will use the data from this link:
# http://wiki.stat.ucla.edu/socr/index.php/SOCR_Data_LA_Neighborhoods_Data
# Although this table contains the population as well, we decide not to extract it from here since it's a bit old (2010)
website_url = requests.get('http://wiki.stat.ucla.edu/socr/index.php/SOCR_Data_LA_Neighborhoods_Data').text
soup = BeautifulSoup(website_url,'html')
# soup.prettify()
area_table = soup.findAll('table',{'class':'wikitable'})[1].findAll('tr')[1:]

# %%
for row in area_table:
    neighbor_name = row.findAll('td')[0].a.renderContents().strip().decode("utf-8").replace("_", " ").replace("-", " ")
    population = float(row.findAll('td')[11].renderContents())
    area = float(row.findAll('td')[12].renderContents())
    if any(neighborhoods_df['Neighborhood'] == neighbor_name):
        neighborhoods_df.loc[neighborhoods_df['Neighborhood'] == neighbor_name, 'Population'] = population
        neighborhoods_df.loc[neighborhoods_df['Neighborhood'] == neighbor_name, 'Area'] = area

# %%
# Drop the neighborhoods for which the area data is missing
neighborhoods_df = neighborhoods_df[neighborhoods_df['Area'] != 0].reset_index(drop=True)
neighborhoods_df = neighborhoods_df[neighborhoods_df['Population'] != 0].reset_index(drop=True)
print('There are {} neighborhoods in the dataframe.'.format(neighborhoods_df.shape[0]))
neighborhoods_df.head(10)
# Out:
# There are 108 neighborhoods in the dataframe.
#              Neighborhood   Latitude   Longitude  Population  Area
# 0                  Arleta  34.241327 -118.432205     31068.0   3.1
# 1       Arlington Heights  34.043494 -118.321374     22106.0   1.0
# 2         Atwater Village  34.118698 -118.262392     14888.0   1.8
# 3  Baldwin Hills/Crenshaw  34.007568 -118.350596     30123.0   3.0
# 4                 Bel Air  34.098883 -118.459881      7928.0   6.6
# 5           Beverly Crest  34.116770 -118.432261     10610.0   7.9
# 6           Beverly Grove  34.076034 -118.369972     21417.0   1.7
# 7             Beverlywood  34.046633 -118.395038      6080.0   0.8
# 8           Boyle Heights  34.043689 -118.209768     92785.0   6.5
# 9               Brentwood  34.052140 -118.474070     31344.0  15.2

# %%
neighborhoods_df['Population density'] = round(neighborhoods_df['Population'] / neighborhoods_df['Area'])
neighborhoods_df.head(10)
# Out:
#              Neighborhood   Latitude   Longitude  Population  Area  \
# 0                  Arleta  34.241327 -118.432205     31068.0   3.1
# 1       Arlington Heights  34.043494 -118.321374     22106.0   1.0
# 2         Atwater Village  34.118698 -118.262392     14888.0   1.8
# 3  Baldwin Hills/Crenshaw  34.007568 -118.350596     30123.0   3.0
# 4                 Bel Air  34.098883 -118.459881      7928.0   6.6
# 5           Beverly Crest  34.116770 -118.432261     10610.0   7.9
# 6           Beverly Grove  34.076034 -118.369972     21417.0   1.7
# 7             Beverlywood  34.046633 -118.395038      6080.0   0.8
# 8           Boyle Heights  34.043689 -118.209768     92785.0   6.5
# 9               Brentwood  34.052140 -118.474070     31344.0  15.2
#
#    Population density
# 0             10022.0
# 1             22106.0
# 2              8271.0
# 3             10041.0
# 4              1201.0
# 5              1343.0
# 6             12598.0
# 7              7600.0
# 8             14275.0
# 9              2062.0

# %%
# MAP VISUALISATION

# get the address of Los Angeles
address = 'Los Angeles, US'
geolocator = Nominatim(user_agent="LA_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Los Angeles are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Los Angeles are 34.0536909, -118.2427666.

# %%
# create map of Los Angeles using latitude and longitude values
map_LA = folium.Map(location=[latitude, longitude], zoom_start=10)

# add markers to map
for lat, lng, neighborhood, pop in zip(neighborhoods_df['Latitude'], neighborhoods_df['Longitude'], neighborhoods_df['Neighborhood'], neighborhoods_df['Population density']):
    label = '{}, density {}/km'.format(neighborhood, pop)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius= 5 * (pop / 10000),
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_LA)  
    
map_LA
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Define foursquare credentials
CLIENT_ID = 'QED5T4EOYGPHTLNIPYLSVINTSUYSVZ30GZBMENBIXAPBNVLN' # Foursquare ID
CLIENT_SECRET = 'DRNUECJTLEUK2HLDNIM0DMHN3IMOB0C0XHYTKYSWFV120AL1' # Foursquare Secret
VERSION = '20200416' # API version
LIMIT = 100
radius = 500
